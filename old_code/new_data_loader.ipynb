# %%
import numpy as np
from SPV_utils import *

# %%
import matplotlib.pyplot as plt

# %%
# v0 = 0.25
# i = 3
# path = rf"Data_small_v0\Data\coordinate_p0=3.80_v0={v0:.2f}_pin=0_set_{i}.npy"
# arr = np.load(path)

# %%
# arr.shape

# %%
timestamps, arr = get_data_from_npy(rf"Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_3.npy")
print(arr.shape)
# Out:
# (312, 1024, 2)

# %%
plt.plot(timestamps, MSD(arr))

# %%
data = get_all_data_npy(rf"Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_*")
# Out:
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_1.npy
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_2.npy
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_3.npy
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_4.npy
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_5.npy
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_6.npy
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_7.npy
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_8.npy
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_9.npy
# Data_small_v0\Data\coordinate_p0=3.80_v0=0.25_pin=0_set_10.npy
